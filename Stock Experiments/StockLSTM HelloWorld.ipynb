# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'
dataset_train = pd.read_csv(url)
training_set = dataset_train.iloc[:, 1:2].values
dataset_train.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914  \
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

X_train = []
y_train = []

for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
    
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# 2023-04-30 10:10:51.697199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-30 10:10:51.709955: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-04-30 10:10:51.849431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:51.850216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:51.850897: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:51.972570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:51.973517: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:51.974189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:52.095239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:52.096120: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:52.096863: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/100
# 2023-04-30 10:10:52.221409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:52.222335: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:52.222990: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:52.422297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:52.423561: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:52.424530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:52.542383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:52.543185: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:52.543903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:52.659210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:52.660211: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:52.660957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:52.776270: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:52.777069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:52.777783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:53.644583: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:53.645601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:53.646336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:53.873125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:53.874111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:53.874863: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:53.987632: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:53.988424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:53.989142: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:10:54.102856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:10:54.103836: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:10:54.104543: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 62/62 [==============================] - 6s 42ms/step - loss: 0.0118
# Epoch 2/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0030
# Epoch 3/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0026
# Epoch 4/100
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0024
# Epoch 5/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0025
# Epoch 6/100
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0025
# Epoch 7/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0021
# Epoch 8/100
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0021
# Epoch 9/100
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0020
# Epoch 10/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 11/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0020
# Epoch 12/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0018
# Epoch 13/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0017
# Epoch 14/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0017
# Epoch 15/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0019
# Epoch 16/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0018
# Epoch 17/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0015
# Epoch 18/100
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0015
# Epoch 19/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0016
# Epoch 20/100
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0014
# Epoch 21/100
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0013
# Epoch 22/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 23/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0014
# Epoch 24/100
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0015
# Epoch 25/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 26/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0013
# Epoch 27/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0012
# Epoch 28/100
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0013
# Epoch 29/100
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0012
# Epoch 30/100
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0012
# Epoch 31/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0012
# Epoch 32/100
# 62/62 [==============================] - 3s 40ms/step - loss: 0.0011
# Epoch 33/100
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0012
# Epoch 34/100
# 62/62 [==============================] - 3s 43ms/step - loss: 9.6024e-04
# Epoch 35/100
# 62/62 [==============================] - 3s 42ms/step - loss: 9.8214e-04
# Epoch 36/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0010
# Epoch 37/100
# 62/62 [==============================] - 3s 40ms/step - loss: 0.0010
# Epoch 38/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0010
# Epoch 39/100
# 62/62 [==============================] - 3s 40ms/step - loss: 8.5471e-04
# Epoch 40/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0010
# Epoch 41/100
# 62/62 [==============================] - 3s 41ms/step - loss: 9.1113e-04
# Epoch 42/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0010
# Epoch 43/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0010
# Epoch 44/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.9569e-04
# Epoch 45/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.7840e-04
# Epoch 46/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0010
# Epoch 47/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.8014e-04
# Epoch 48/100
# 62/62 [==============================] - 3s 40ms/step - loss: 8.9682e-04
# Epoch 49/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.5281e-04
# Epoch 50/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.1427e-04
# Epoch 51/100
# 62/62 [==============================] - 3s 40ms/step - loss: 7.7718e-04
# Epoch 52/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.3228e-04
# Epoch 53/100
# 62/62 [==============================] - 2s 39ms/step - loss: 9.0679e-04
# Epoch 54/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.5679e-04
# Epoch 55/100
# 62/62 [==============================] - 2s 40ms/step - loss: 9.2808e-04
# Epoch 56/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.7834e-04
# Epoch 57/100
# 62/62 [==============================] - 3s 40ms/step - loss: 8.3176e-04
# Epoch 58/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.0298e-04
# Epoch 59/100
# 62/62 [==============================] - 3s 41ms/step - loss: 9.3722e-04
# Epoch 60/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.7428e-04
# Epoch 61/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.5476e-04
# Epoch 62/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.1885e-04
# Epoch 63/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.3217e-04
# Epoch 64/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.8876e-04
# Epoch 65/100
# 62/62 [==============================] - 2s 37ms/step - loss: 7.3967e-04
# Epoch 66/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.5232e-04
# Epoch 67/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.3653e-04
# Epoch 68/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.7436e-04
# Epoch 69/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.3943e-04
# Epoch 70/100
# 62/62 [==============================] - 2s 40ms/step - loss: 6.6438e-04
# Epoch 71/100
# 62/62 [==============================] - 3s 40ms/step - loss: 6.5013e-04
# Epoch 72/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.3593e-04
# Epoch 73/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.2411e-04
# Epoch 74/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.2922e-04
# Epoch 75/100
# 62/62 [==============================] - 3s 42ms/step - loss: 6.2013e-04
# Epoch 76/100
# 62/62 [==============================] - 3s 42ms/step - loss: 5.8885e-04
# Epoch 77/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.1941e-04
# Epoch 78/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.0799e-04
# Epoch 79/100
# 62/62 [==============================] - 3s 42ms/step - loss: 6.4685e-04
# Epoch 80/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.6032e-04
# Epoch 81/100
# 62/62 [==============================] - 3s 42ms/step - loss: 6.7857e-04
# Epoch 82/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.7705e-04
# Epoch 83/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.5251e-04
# Epoch 84/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.1767e-04
# Epoch 85/100
# 62/62 [==============================] - 3s 41ms/step - loss: 5.8959e-04
# Epoch 86/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.2573e-04
# Epoch 87/100
# 62/62 [==============================] - 3s 42ms/step - loss: 6.6492e-04
# Epoch 88/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.0120e-04
# Epoch 89/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.1729e-04
# Epoch 90/100
# 62/62 [==============================] - 2s 40ms/step - loss: 6.2674e-04
# Epoch 91/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.0585e-04
# Epoch 92/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.8278e-04
# Epoch 93/100
# 62/62 [==============================] - 3s 40ms/step - loss: 8.2308e-04
# Epoch 94/100
# 62/62 [==============================] - 3s 40ms/step - loss: 6.8546e-04
# Epoch 95/100
# 62/62 [==============================] - 2s 39ms/step - loss: 6.4234e-04
# Epoch 96/100
# 62/62 [==============================] - 2s 37ms/step - loss: 6.4575e-04
# Epoch 97/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.5079e-04
# Epoch 98/100
# 62/62 [==============================] - 2s 40ms/step - loss: 6.6066e-04
# Epoch 99/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.0907e-04
# Epoch 100/100
# 62/62 [==============================] - 2s 40ms/step - loss: 7.7539e-04

# %%
url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/tatatest.csv'
dataset_test = pd.read_csv(url)
real_stock_price = dataset_test.iloc[:, 1:2].values

dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

plt.plot(real_stock_price, color = 'black', label = 'TATA Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TATA Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()
# Out:
# 2023-04-30 10:16:22.930014: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:16:22.930948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:16:22.931617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:16:23.046362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:16:23.047183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:16:23.047860: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:16:23.161988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:16:23.162920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:16:23.163608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-30 10:16:23.280521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-30 10:16:23.281270: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-30 10:16:23.281966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 1s 696ms/step
